# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
 dataset=pd.read_csv('C:/Users/DELL/Desktop/WineQT.csv')
 dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
dataset.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
missing_data=pd.DataFrame({'total_missing':dataset.isnull().sum(),'perc_missing':(dataset.isnull().sum()/82790)*100})
missing_data
# Out:
#                       total_missing  perc_missing
# fixed acidity                     0           0.0
# volatile acidity                  0           0.0
# citric acid                       0           0.0
# residual sugar                    0           0.0
# chlorides                         0           0.0
# free sulfur dioxide               0           0.0
# total sulfur dioxide              0           0.0
# density                           0           0.0
# pH                                0           0.0
# sulphates                         0           0.0
# alcohol                           0           0.0
# quality                           0           0.0
# Id                                0           0.0

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
num_cols=['fixed acidity','volatile acidity','citric acid','residual sugar']
plt.figure(figsize=(18,9))
dataset[num_cols].boxplot()
plt.title('NUMERICAL VARIABLES IN WINE QUALITY DATASET',fontsize=20)
plt.show()

# %%
dataset.sort_values(by=['Id'],ascending=False).head(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1142            5.9             0.645         0.12             2.0      0.075
# 1141            5.9             0.550         0.10             2.2      0.062
# 1140            6.2             0.600         0.08             2.0      0.090
# 1139            6.8             0.620         0.08             1.9      0.068
# 1138            6.3             0.510         0.13             2.3      0.076
# 1137            5.4             0.740         0.09             1.7      0.089
# 1136            6.3             0.550         0.15             1.8      0.077
# 1135            5.8             0.610         0.11             1.8      0.066
# 1134            7.5             0.310         0.41             2.4      0.065
# 1133            6.7             0.320         0.44             2.4      0.061
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots(6,2,figsize=(15,30))
sns.countplot(x=dataset.quality,ax=ax[0][0]).set_title('Target Distribution',size=15)
sns.boxplot(x=dataset.quality,y=dataset['volatile acidity'],ax=ax[0][1])
sns.boxplot(x=dataset.quality,y=dataset['citric acid'],ax=ax[1][0])
sns.boxplot(x=dataset.quality,y=dataset['residual sugar'],ax=ax[1][1])
sns.boxplot(x=dataset.quality,y=dataset['chlorides'],ax=ax[2][0])
sns.boxplot(x=dataset.quality,y=dataset['free sulfur dioxide'],ax=ax[2][1])
sns.boxplot(x=dataset.quality,y=dataset['total sulfur dioxide'],ax=ax[3][0])
sns.boxplot(x=dataset.quality,y=dataset['density'],ax=ax[3][1])
sns.boxplot(x=dataset.quality,y=dataset['pH'],ax=ax[4][0])
sns.boxplot(x=dataset.quality,y=dataset['sulphates'],ax=ax[4][1])
sns.boxplot(x=dataset.quality,y=dataset['alcohol'],ax=ax[5][0])
sns.boxplot(x=dataset.quality,y=dataset['fixed acidity'],ax=ax[5][1])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
 corr=dataset.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr, annot=True, cmap="Blues", annot_kws={"fontsize":12})
plt.title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
dataset.hist(figsize=(20,15),bins='auto', color='#52527a')
plt.show()

# %%
plt.figure(figsize=(10,8))
skewness=dataset.skew().sort_values()
sns.barplot(x=skewness,y=skewness.index).set_title('The Skewness of features')
plt.axvline(x=1, color='r', linestyle='--')
plt.xlabel('Skewness')
# Out:
# Text(0.5, 0, 'Skewness')

# %%
plt.figure(figsize=(14,6))
corr = dataset.corr()['quality'].sort_values(ascending=False)
corr.drop('quality').plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import RobustScaler

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
import sklearn.metrics as metrics

# %%
# !pip install plotly

# %%
import plotly.express as plt
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('C:/Users/DELL/Desktop/WineQT.csv')
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
dataset.shape
# Out:
# (1143, 13)

# %%
X=dataset.drop('quality',axis=1)
y=dataset['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.20)

# %%
from sklearn.svm import SVC
svclassifier=SVC(kernel='linear')
svclassifier.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 0  4  0  1  0]
#  [ 0 73 27  0  0]
#  [ 0 27 55  9  0]
#  [ 0  1 24  5  0]
#  [ 0  0  2  1  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         5
#            5       0.70      0.73      0.71       100
#            6       0.51      0.60      0.55        91
#            7       0.31      0.17      0.22        30
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.58       229
#    macro avg       0.30      0.30      0.30       229
# weighted avg       0.55      0.58      0.56       229
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
